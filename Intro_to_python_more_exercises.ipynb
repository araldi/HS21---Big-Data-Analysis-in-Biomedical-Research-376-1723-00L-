# %% [markdown]
# <a href="https://colab.research.google.com/github/araldi/HS21---Big-Data-Analysis-in-Biomedical-Research-376-1723-00L-/blob/main/Intro_to_python_more_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## A couple more things to learn
#
# ### built-in function enumerate()
# enumerate() loops over an iterable object and keep track of how many iterations have occurred.

# %%
# enumerate() example

months = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']

for iteration, element in enumerate(months):
  print("iteration: ", iteration)
  print("element name: ", element)

# %%
for iteration, element in enumerate(months):
  print("month number {} is {}".format(iteration +1, element))

# %%
for iteration, element in enumerate(months):
  print("month number {month_number} is {element}".format(month_number = iteration +1, element = element))

# %% [markdown]
# ### Function
#
# A function is a block of code which only runs when it is called.
#
# You can pass data, known as parameters, into a function.
#
# A function can return data as a result.
#
# It increases the readability of the code, and allows for faster coding of repetitive operations.

# %%
# synthax of a function

def boring_sum_function(parameter1, parameter2):
  sum = parameter1 + parameter2
  return sum

# note that nothing happens when the cell is run

# %%
#minimal function

def boring_sum_function(parameter1, parameter2):
  return parameter1 + parameter2

# %%
# call the function
boring_sum_function(1,3)

# %%
# try again
boring_sum_function("boring",3)

# %%
# try again
boring_sum_function(1,3,4)

# %%
def less_boring_sum_function(parameter1, parameter2):
  '''
  DOCSTRING:
  this functions returns the sum of the two parameters
  '''
  sum = parameter1 + parameter2
  print("I will now return the sum of the input parameters:")
  return sum

# %%
less_boring_sum_function?

# %%
help(less_boring_sum_function)

# %%
less_boring_sum_function(1, 2)

# %% [markdown]
# ## if-else, for loop exercises

# %% [markdown]
# #### A calendar

# %% [markdown]
# Create a for loop (possibly a nested for loop) which writes out
# the month, day, and day of the week for each day of the year
# and that works for both years with 28 days in feb, and 29 days in feb
# just by changing the value of the variable feb
# it should look like this, in the case of a year starting on a Monday (simplest case)

# %%
days_of_the_week = ['M','Tue','W','Thr','F','Sat','Sun']
months = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
feb = 29
month_lenght = [31, feb, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]

# %% [markdown]
# The output could be like this, for example:

# %%
week_index = 0

#for example....
for index, month in enumerate(months):  
#   ## your solution
# Out:
# 1 Jan M
# 2 Jan Tue
# 3 Jan W
# 4 Jan Thr
# 5 Jan F
# 6 Jan Sat
# 7 Jan Sun
# 8 Jan M
# 9 Jan Tue
# 10 Jan W
# 11 Jan Thr
# 12 Jan F
# 13 Jan Sat
# 14 Jan Sun
# 15 Jan M
# 16 Jan Tue
# 17 Jan W
# 18 Jan Thr
# 19 Jan F
# 20 Jan Sat
# 21 Jan Sun
# 22 Jan M
# 23 Jan Tue
# 24 Jan W
# 25 Jan Thr
# 26 Jan F
# 27 Jan Sat
# 28 Jan Sun
# 29 Jan M
# 30 Jan Tue
# 31 Jan W
# 1 Feb Thr
# 2 Feb F
# 3 Feb Sat
# 4 Feb Sun
# 5 Feb M
# 6 Feb Tue
# 7 Feb W
# 8 Feb Thr
# 9 Feb F
# 10 Feb Sat
# 11 Feb Sun
# 12 Feb M
# 13 Feb Tue
# 14 Feb W
# 15 Feb Thr
# 16 Feb F
# 17 Feb Sat
# 18 Feb Sun
# 19 Feb M
# 20 Feb Tue
# 21 Feb W
# 22 Feb Thr
# 23 Feb F
# 24 Feb Sat
# 25 Feb Sun
# 26 Feb M
# 27 Feb Tue
# 28 Feb W
# 29 Feb Thr
# 1 Mar F
# 2 Mar Sat
# 3 Mar Sun
# 4 Mar M
# 5 Mar Tue
# 6 Mar W
# 7 Mar Thr
# 8 Mar F
# 9 Mar Sat
# 10 Mar Sun
# 11 Mar M
# 12 Mar Tue
# 13 Mar W
# 14 Mar Thr
# 15 Mar F
# 16 Mar Sat
# 17 Mar Sun
# 18 Mar M
# 19 Mar Tue
# 20 Mar W
# 21 Mar Thr
# 22 Mar F
# 23 Mar Sat
# 24 Mar Sun
# 25 Mar M
# 26 Mar Tue
# 27 Mar W
# 28 Mar Thr
# 29 Mar F
# 30 Mar Sat
# 31 Mar Sun
# 1 Apr M
# 2 Apr Tue
# 3 Apr W
# 4 Apr Thr
# 5 Apr F
# 6 Apr Sat
# 7 Apr Sun
# 8 Apr M
# 9 Apr Tue
# 10 Apr W
# 11 Apr Thr
# 12 Apr F
# 13 Apr Sat
# 14 Apr Sun
# 15 Apr M
# 16 Apr Tue
# 17 Apr W
# 18 Apr Thr
# 19 Apr F
# 20 Apr Sat
# 21 Apr Sun
# 22 Apr M
# 23 Apr Tue
# 24 Apr W
# 25 Apr Thr
# 26 Apr F
# 27 Apr Sat
# 28 Apr Sun
# 29 Apr M
# 30 Apr Tue
# 1 May W
# 2 May Thr
# 3 May F
# 4 May Sat
# 5 May Sun
# 6 May M
# 7 May Tue
# 8 May W
# 9 May Thr
# 10 May F
# 11 May Sat
# 12 May Sun
# 13 May M
# 14 May Tue
# 15 May W
# 16 May Thr
# 17 May F
# 18 May Sat
# 19 May Sun
# 20 May M
# 21 May Tue
# 22 May W
# 23 May Thr
# 24 May F
# 25 May Sat
# 26 May Sun
# 27 May M
# 28 May Tue
# 29 May W
# 30 May Thr
# 31 May F
# 1 Jun Sat
# 2 Jun Sun
# 3 Jun M
# 4 Jun Tue
# 5 Jun W
# 6 Jun Thr
# 7 Jun F
# 8 Jun Sat
# 9 Jun Sun
# 10 Jun M
# 11 Jun Tue
# 12 Jun W
# 13 Jun Thr
# 14 Jun F
# 15 Jun Sat
# 16 Jun Sun
# 17 Jun M
# 18 Jun Tue
# 19 Jun W
# 20 Jun Thr
# 21 Jun F
# 22 Jun Sat
# 23 Jun Sun
# 24 Jun M
# 25 Jun Tue
# 26 Jun W
# 27 Jun Thr
# 28 Jun F
# 29 Jun Sat
# 30 Jun Sun
# 1 Jul M
# 2 Jul Tue
# 3 Jul W
# 4 Jul Thr
# 5 Jul F
# 6 Jul Sat
# 7 Jul Sun
# 8 Jul M
# 9 Jul Tue
# 10 Jul W
# 11 Jul Thr
# 12 Jul F
# 13 Jul Sat
# 14 Jul Sun
# 15 Jul M
# 16 Jul Tue
# 17 Jul W
# 18 Jul Thr
# 19 Jul F
# 20 Jul Sat
# 21 Jul Sun
# 22 Jul M
# 23 Jul Tue
# 24 Jul W
# 25 Jul Thr
# 26 Jul F
# 27 Jul Sat
# 28 Jul Sun
# 29 Jul M
# 30 Jul Tue
# 31 Jul W
# 1 Aug Thr
# 2 Aug F
# 3 Aug Sat
# 4 Aug Sun
# 5 Aug M
# 6 Aug Tue
# 7 Aug W
# 8 Aug Thr
# 9 Aug F
# 10 Aug Sat
# 11 Aug Sun
# 12 Aug M
# 13 Aug Tue
# 14 Aug W
# 15 Aug Thr
# 16 Aug F
# 17 Aug Sat
# 18 Aug Sun
# 19 Aug M
# 20 Aug Tue
# 21 Aug W
# 22 Aug Thr
# 23 Aug F
# 24 Aug Sat
# 25 Aug Sun
# 26 Aug M
# 27 Aug Tue
# 28 Aug W
# 29 Aug Thr
# 30 Aug F
# 31 Aug Sat
# 1 Sep Sun
# 2 Sep M
# 3 Sep Tue
# 4 Sep W
# 5 Sep Thr
# 6 Sep F
# 7 Sep Sat
# 8 Sep Sun
# 9 Sep M
# 10 Sep Tue
# 11 Sep W
# 12 Sep Thr
# 13 Sep F
# 14 Sep Sat
# 15 Sep Sun
# 16 Sep M
# 17 Sep Tue
# 18 Sep W
# 19 Sep Thr
# 20 Sep F
# 21 Sep Sat
# 22 Sep Sun
# 23 Sep M
# 24 Sep Tue
# 25 Sep W
# 26 Sep Thr
# 27 Sep F
# 28 Sep Sat
# 29 Sep Sun
# 30 Sep M
# 1 Oct Tue
# 2 Oct W
# 3 Oct Thr
# 4 Oct F
# 5 Oct Sat
# 6 Oct Sun
# 7 Oct M
# 8 Oct Tue
# 9 Oct W
# 10 Oct Thr
# 11 Oct F
# 12 Oct Sat
# 13 Oct Sun
# 14 Oct M
# 15 Oct Tue
# 16 Oct W
# 17 Oct Thr
# 18 Oct F
# 19 Oct Sat
# 20 Oct Sun
# 21 Oct M
# 22 Oct Tue
# 23 Oct W
# 24 Oct Thr
# 25 Oct F
# 26 Oct Sat
# 27 Oct Sun
# 28 Oct M
# 29 Oct Tue
# 30 Oct W
# 31 Oct Thr
# 1 Nov F
# 2 Nov Sat
# 3 Nov Sun
# 4 Nov M
# 5 Nov Tue
# 6 Nov W
# 7 Nov Thr
# 8 Nov F
# 9 Nov Sat
# 10 Nov Sun
# 11 Nov M
# 12 Nov Tue
# 13 Nov W
# 14 Nov Thr
# 15 Nov F
# 16 Nov Sat
# 17 Nov Sun
# 18 Nov M
# 19 Nov Tue
# 20 Nov W
# 21 Nov Thr
# 22 Nov F
# 23 Nov Sat
# 24 Nov Sun
# 25 Nov M
# 26 Nov Tue
# 27 Nov W
# 28 Nov Thr
# 29 Nov F
# 30 Nov Sat
# 1 Dec Sun
# 2 Dec M
# 3 Dec Tue
# 4 Dec W
# 5 Dec Thr
# 6 Dec F
# 7 Dec Sat
# 8 Dec Sun
# 9 Dec M
# 10 Dec Tue
# 11 Dec W
# 12 Dec Thr
# 13 Dec F
# 14 Dec Sat
# 15 Dec Sun
# 16 Dec M
# 17 Dec Tue
# 18 Dec W
# 19 Dec Thr
# 20 Dec F
# 21 Dec Sat
# 22 Dec Sun
# 23 Dec M
# 24 Dec Tue
# 25 Dec W
# 26 Dec Thr
# 27 Dec F
# 28 Dec Sat
# 29 Dec Sun
# 30 Dec M
# 31 Dec Tue

# %% [markdown]
# Can you recreate an output like this?

# %%
#HINT
# Use a dictionary to choose the appropriate the suffix
day_suffix_dict = {1: 'st', 2 : 'nd', 3: 'rd'}
# Out:
# The 1st of Jan is a M
# The 2nd of Jan is a Tue
# The 3rd of Jan is a W
# The 4th of Jan is a Thr
# The 5th of Jan is a F
# The 6th of Jan is a Sat
# The 7th of Jan is a Sun
# The 8th of Jan is a M
# The 9th of Jan is a Tue
# The 10th of Jan is a W
# The 11th of Jan is a Thr
# The 12th of Jan is a F
# The 13th of Jan is a Sat
# The 14th of Jan is a Sun
# The 15th of Jan is a M
# The 16th of Jan is a Tue
# The 17th of Jan is a W
# The 18th of Jan is a Thr
# The 19th of Jan is a F
# The 20th of Jan is a Sat
# The 21th of Jan is a Sun
# The 22th of Jan is a M
# The 23th of Jan is a Tue
# The 24th of Jan is a W
# The 25th of Jan is a Thr
# The 26th of Jan is a F
# The 27th of Jan is a Sat
# The 28th of Jan is a Sun
# The 29th of Jan is a M
# The 30th of Jan is a Tue
# The 31th of Jan is a W
# The 1st of Feb is a Thr
# The 2nd of Feb is a F
# The 3rd of Feb is a Sat
# The 4th of Feb is a Sun
# The 5th of Feb is a M
# The 6th of Feb is a Tue
# The 7th of Feb is a W
# The 8th of Feb is a Thr
# The 9th of Feb is a F
# The 10th of Feb is a Sat
# The 11th of Feb is a Sun
# The 12th of Feb is a M
# The 13th of Feb is a Tue
# The 14th of Feb is a W
# The 15th of Feb is a Thr
# The 16th of Feb is a F
# The 17th of Feb is a Sat
# The 18th of Feb is a Sun
# The 19th of Feb is a M
# The 20th of Feb is a Tue
# The 21th of Feb is a W
# The 22th of Feb is a Thr
# The 23th of Feb is a F
# The 24th of Feb is a Sat
# The 25th of Feb is a Sun
# The 26th of Feb is a M
# The 27th of Feb is a Tue
# The 28th of Feb is a W
# The 29th of Feb is a Thr
# The 1st of Mar is a F
# The 2nd of Mar is a Sat
# The 3rd of Mar is a Sun
# The 4th of Mar is a M
# The 5th of Mar is a Tue
# The 6th of Mar is a W
# The 7th of Mar is a Thr
# The 8th of Mar is a F
# The 9th of Mar is a Sat
# The 10th of Mar is a Sun
# The 11th of Mar is a M
# The 12th of Mar is a Tue
# The 13th of Mar is a W
# The 14th of Mar is a Thr
# The 15th of Mar is a F
# The 16th of Mar is a Sat
# The 17th of Mar is a Sun
# The 18th of Mar is a M
# The 19th of Mar is a Tue
# The 20th of Mar is a W
# The 21th of Mar is a Thr
# The 22th of Mar is a F
# The 23th of Mar is a Sat
# The 24th of Mar is a Sun
# The 25th of Mar is a M
# The 26th of Mar is a Tue
# The 27th of Mar is a W
# The 28th of Mar is a Thr
# The 29th of Mar is a F
# The 30th of Mar is a Sat
# The 31th of Mar is a Sun
# The 1st of Apr is a M
# The 2nd of Apr is a Tue
# The 3rd of Apr is a W
# The 4th of Apr is a Thr
# The 5th of Apr is a F
# The 6th of Apr is a Sat
# The 7th of Apr is a Sun
# The 8th of Apr is a M
# The 9th of Apr is a Tue
# The 10th of Apr is a W
# The 11th of Apr is a Thr
# The 12th of Apr is a F
# The 13th of Apr is a Sat
# The 14th of Apr is a Sun
# The 15th of Apr is a M
# The 16th of Apr is a Tue
# The 17th of Apr is a W
# The 18th of Apr is a Thr
# The 19th of Apr is a F
# The 20th of Apr is a Sat
# The 21th of Apr is a Sun
# The 22th of Apr is a M
# The 23th of Apr is a Tue
# The 24th of Apr is a W
# The 25th of Apr is a Thr
# The 26th of Apr is a F
# The 27th of Apr is a Sat
# The 28th of Apr is a Sun
# The 29th of Apr is a M
# The 30th of Apr is a Tue
# The 1st of May is a W
# The 2nd of May is a Thr
# The 3rd of May is a F
# The 4th of May is a Sat
# The 5th of May is a Sun
# The 6th of May is a M
# The 7th of May is a Tue
# The 8th of May is a W
# The 9th of May is a Thr
# The 10th of May is a F
# The 11th of May is a Sat
# The 12th of May is a Sun
# The 13th of May is a M
# The 14th of May is a Tue
# The 15th of May is a W
# The 16th of May is a Thr
# The 17th of May is a F
# The 18th of May is a Sat
# The 19th of May is a Sun
# The 20th of May is a M
# The 21th of May is a Tue
# The 22th of May is a W
# The 23th of May is a Thr
# The 24th of May is a F
# The 25th of May is a Sat
# The 26th of May is a Sun
# The 27th of May is a M
# The 28th of May is a Tue
# The 29th of May is a W
# The 30th of May is a Thr
# The 31th of May is a F
# The 1st of Jun is a Sat
# The 2nd of Jun is a Sun
# The 3rd of Jun is a M
# The 4th of Jun is a Tue
# The 5th of Jun is a W
# The 6th of Jun is a Thr
# The 7th of Jun is a F
# The 8th of Jun is a Sat
# The 9th of Jun is a Sun
# The 10th of Jun is a M
# The 11th of Jun is a Tue
# The 12th of Jun is a W
# The 13th of Jun is a Thr
# The 14th of Jun is a F
# The 15th of Jun is a Sat
# The 16th of Jun is a Sun
# The 17th of Jun is a M
# The 18th of Jun is a Tue
# The 19th of Jun is a W
# The 20th of Jun is a Thr
# The 21th of Jun is a F
# The 22th of Jun is a Sat
# The 23th of Jun is a Sun
# The 24th of Jun is a M
# The 25th of Jun is a Tue
# The 26th of Jun is a W
# The 27th of Jun is a Thr
# The 28th of Jun is a F
# The 29th of Jun is a Sat
# The 30th of Jun is a Sun
# The 1st of Jul is a M
# The 2nd of Jul is a Tue
# The 3rd of Jul is a W
# The 4th of Jul is a Thr
# The 5th of Jul is a F
# The 6th of Jul is a Sat
# The 7th of Jul is a Sun
# The 8th of Jul is a M
# The 9th of Jul is a Tue
# The 10th of Jul is a W
# The 11th of Jul is a Thr
# The 12th of Jul is a F
# The 13th of Jul is a Sat
# The 14th of Jul is a Sun
# The 15th of Jul is a M
# The 16th of Jul is a Tue
# The 17th of Jul is a W
# The 18th of Jul is a Thr
# The 19th of Jul is a F
# The 20th of Jul is a Sat
# The 21th of Jul is a Sun
# The 22th of Jul is a M
# The 23th of Jul is a Tue
# The 24th of Jul is a W
# The 25th of Jul is a Thr
# The 26th of Jul is a F
# The 27th of Jul is a Sat
# The 28th of Jul is a Sun
# The 29th of Jul is a M
# The 30th of Jul is a Tue
# The 31th of Jul is a W
# The 1st of Aug is a Thr
# The 2nd of Aug is a F
# The 3rd of Aug is a Sat
# The 4th of Aug is a Sun
# The 5th of Aug is a M
# The 6th of Aug is a Tue
# The 7th of Aug is a W
# The 8th of Aug is a Thr
# The 9th of Aug is a F
# The 10th of Aug is a Sat
# The 11th of Aug is a Sun
# The 12th of Aug is a M
# The 13th of Aug is a Tue
# The 14th of Aug is a W
# The 15th of Aug is a Thr
# The 16th of Aug is a F
# The 17th of Aug is a Sat
# The 18th of Aug is a Sun
# The 19th of Aug is a M
# The 20th of Aug is a Tue
# The 21th of Aug is a W
# The 22th of Aug is a Thr
# The 23th of Aug is a F
# The 24th of Aug is a Sat
# The 25th of Aug is a Sun
# The 26th of Aug is a M
# The 27th of Aug is a Tue
# The 28th of Aug is a W
# The 29th of Aug is a Thr
# The 30th of Aug is a F
# The 31th of Aug is a Sat
# The 1st of Sep is a Sun
# The 2nd of Sep is a M
# The 3rd of Sep is a Tue
# The 4th of Sep is a W
# The 5th of Sep is a Thr
# The 6th of Sep is a F
# The 7th of Sep is a Sat
# The 8th of Sep is a Sun
# The 9th of Sep is a M
# The 10th of Sep is a Tue
# The 11th of Sep is a W
# The 12th of Sep is a Thr
# The 13th of Sep is a F
# The 14th of Sep is a Sat
# The 15th of Sep is a Sun
# The 16th of Sep is a M
# The 17th of Sep is a Tue
# The 18th of Sep is a W
# The 19th of Sep is a Thr
# The 20th of Sep is a F
# The 21th of Sep is a Sat
# The 22th of Sep is a Sun
# The 23th of Sep is a M
# The 24th of Sep is a Tue
# The 25th of Sep is a W
# The 26th of Sep is a Thr
# The 27th of Sep is a F
# The 28th of Sep is a Sat
# The 29th of Sep is a Sun
# The 30th of Sep is a M
# The 1st of Oct is a Tue
# The 2nd of Oct is a W
# The 3rd of Oct is a Thr
# The 4th of Oct is a F
# The 5th of Oct is a Sat
# The 6th of Oct is a Sun
# The 7th of Oct is a M
# The 8th of Oct is a Tue
# The 9th of Oct is a W
# The 10th of Oct is a Thr
# The 11th of Oct is a F
# The 12th of Oct is a Sat
# The 13th of Oct is a Sun
# The 14th of Oct is a M
# The 15th of Oct is a Tue
# The 16th of Oct is a W
# The 17th of Oct is a Thr
# The 18th of Oct is a F
# The 19th of Oct is a Sat
# The 20th of Oct is a Sun
# The 21th of Oct is a M
# The 22th of Oct is a Tue
# The 23th of Oct is a W
# The 24th of Oct is a Thr
# The 25th of Oct is a F
# The 26th of Oct is a Sat
# The 27th of Oct is a Sun
# The 28th of Oct is a M
# The 29th of Oct is a Tue
# The 30th of Oct is a W
# The 31th of Oct is a Thr
# The 1st of Nov is a F
# The 2nd of Nov is a Sat
# The 3rd of Nov is a Sun
# The 4th of Nov is a M
# The 5th of Nov is a Tue
# The 6th of Nov is a W
# The 7th of Nov is a Thr
# The 8th of Nov is a F
# The 9th of Nov is a Sat
# The 10th of Nov is a Sun
# The 11th of Nov is a M
# The 12th of Nov is a Tue
# The 13th of Nov is a W
# The 14th of Nov is a Thr
# The 15th of Nov is a F
# The 16th of Nov is a Sat
# The 17th of Nov is a Sun
# The 18th of Nov is a M
# The 19th of Nov is a Tue
# The 20th of Nov is a W
# The 21th of Nov is a Thr
# The 22th of Nov is a F
# The 23th of Nov is a Sat
# The 24th of Nov is a Sun
# The 25th of Nov is a M
# The 26th of Nov is a Tue
# The 27th of Nov is a W
# The 28th of Nov is a Thr
# The 29th of Nov is a F
# The 30th of Nov is a Sat
# The 1st of Dec is a Sun
# The 2nd of Dec is a M
# The 3rd of Dec is a Tue
# The 4th of Dec is a W
# The 5th of Dec is a Thr
# The 6th of Dec is a F
# The 7th of Dec is a Sat
# The 8th of Dec is a Sun
# The 9th of Dec is a M
# The 10th of Dec is a Tue
# The 11th of Dec is a W
# The 12th of Dec is a Thr
# The 13th of Dec is a F
# The 14th of Dec is a Sat
# The 15th of Dec is a Sun
# The 16th of Dec is a M
# The 17th of Dec is a Tue
# The 18th of Dec is a W
# The 19th of Dec is a Thr
# The 20th of Dec is a F
# The 21th of Dec is a Sat
# The 22th of Dec is a Sun
# The 23th of Dec is a M
# The 24th of Dec is a Tue
# The 25th of Dec is a W
# The 26th of Dec is a Thr
# The 27th of Dec is a F
# The 28th of Dec is a Sat
# The 29th of Dec is a Sun
# The 30th of Dec is a M
# The 31th of Dec is a Tue

# %%
# now modify the code to output the nth day of the year

week_index = 0
counter = 0
nth_day = int(input("which day: "))

if nth_day <= 365:

# your code

else:
  print('that day does not exist')
# Out:
# which day: 354
# 19 Dec Thr

# %% [markdown]
# #### Which day of the week?

# %% [markdown]
# Create a code whose output is which day of the week is any day in 2022 (in format dd/mm).
#
# Can you use functions where useful?
#
# 2022 starts on Saturday and February has 28 days

# %%
days_of_the_week = ['M','Tue','W','Thr','F','Sat','Sun']
months = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']

# HINT
# use a dictionary to input the info about the year
year = {'feb' : 28,
        'week_index' : 5,
        'year' : 2022}

#for example
feb = year['feb'] 
month_lenght = [31, feb, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]

week_index = year['week_index']

yyyy = year['year']

# you code ....
# Out:
# Give me a dd/mm date in 2022: 24/09
# 24/09/2022 is a Sat
